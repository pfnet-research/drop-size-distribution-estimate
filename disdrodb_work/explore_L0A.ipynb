# %%
import glob
import pandas as pd
fileall = glob.glob("../disdrodb-data/DISDRODB/Processed/EPFL/EPFL_2009/L0A/??/L0A.EPFL_2009.??.*.V0.parquet")
for file in fileall:
    df = pd.read_parquet(file)
    print(file, df["number_particles"].max())

# %%
import matplotlib.pyplot as plt
df = pd.read_parquet("../disdrodb-data/DISDRODB/Processed/EPFL/EPFL_2009/L0A/32/L0A.EPFL_2009.32.s20090324000000.e20090324235940.V0.parquet")
plt.plot(df["rainfall_accumulated_32bit"])
plt.plot(df["rainfall_rate_32bit"])
#plt.plot(df["raw_drop_average_velocity"])

# %%
df["raw_drop_average_velocity"][400]

# %%
# the data is binned

# %%
len(df["raw_drop_number"][400].split(","))

# %%
import netcdf4

# %%
import netCDF4

# %%
df["time"]

# %%
df.keys()

# %%
df["number_particles"].max()

# %%
from disdrodb.l0.check_configs import check_sensor_configs

sensor_name = "OTT_Parsivel"  # Change with your sensor_name
check_sensor_configs(sensor_name)
